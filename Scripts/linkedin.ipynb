# %% [markdown]
# <a href="https://colab.research.google.com/github/TK-Problem/Python-mokymai/blob/master/Scripts/linkedin.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#@title Importuoti paketus

# duomenų atsisiuntimui per API
import requests

# reikalinga atsiųstą tekstą paversti į json/dict
import json

# paketai dirbti su skaičiais ir duomenimis
import pandas as pd
import numpy as np

# %% [markdown]
# Norint atsisųsti LinkedIn darbo pasiųlymų duomenis, reikia:
#
# 1. užsiregistruoti rapid api svetainėje https://rapidapi.com/.
# 2. užsisakyti nemokamą planą https://rapidapi.com/letscrape-6bRBa3QguO5/api/jsearch/ . Leidžia nemokamai tlikti 50 paieškas/užklausas per mėnesį.
# 3. išsisaugoti savo API raktą, jo reikės atliekant užklausas.

# %%
#@title Atsisiųsti duomenis
# paieškos žodis
SEARCH = 'python lithuania' # @param {type:"string"}
# pasiimti iš RapidAPI
API = '' # @param {type:"string"}

assert API != '', "Įveskite API raktą"

# kiek puslapių ieškoti
# Note: requests for more than one page and up to 10 pages are charged x2 and
# requests for more than 10 pages are charged 3x.
NUM_PAGES = '10' # @param {type:"string"}

# API url
url = "https://jsearch.p.rapidapi.com/search"

# generate query string
querystring = {"query": SEARCH,"num_pages": NUM_PAGES}

# create header for
headers = {
	"X-RapidAPI-Key": API,
	"X-RapidAPI-Host": "jsearch.p.rapidapi.com"
}

# get response
response = requests.request("GET", url, headers=headers, params=querystring)

# %%
#@title Suformatuoti duomenis
# convert to json
output = json.loads(response.text)

# convert to pandas DataFrame
df = pd.DataFrame(output['data'])

# print message
print(f'Pagal paiešką "{SEARCH}" buvo rasti {len(df)} darbo skelbimai.')

# send message
df.head()
# Out:
# Pagal paiešką "python lithuania" buvo rasti 43 darbo skelbimai.
#           employer_name                                      employer_logo  \
# 0               Girteka  https://clean-trucking.eu/wp-content/uploads/2...
# 1  Adroiti Technologies  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 2               Satalia  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 3          Perfection42  https://res.cloudinary.com/crunchbase-producti...
# 4             Canonical  https://upload.wikimedia.org/wikipedia/commons...
#
#               employer_website employer_company_type job_publisher  \
# 0        http://www.girteka.eu             Logistics      LinkedIn
# 1                         None                  None      LinkedIn
# 2      https://www.satalia.com                  None      LinkedIn
# 3  http://www.perfection42.com                  None      LinkedIn
# 4     http://www.canonical.com           Information      LinkedIn
#
#                      job_id job_employment_type  \
# 0  AYrGBHb14Q8AAAAAAAAAAA==            FULLTIME
# 1  5vb_zV1WqJ0AAAAAAAAAAA==            FULLTIME
# 2  5a82dA-6K_cAAAAAAAAAAA==            FULLTIME
# 3  VMdE_oB2wfIAAAAAAAAAAA==            FULLTIME
# 4  lXktIqoybDIAAAAAAAAAAA==            FULLTIME
#
#                             job_title  \
# 0                    Python Developer
# 1                    Python Developer
# 2                    Python Developer
# 3                     Python Engineer
# 4  Software Engineer - Python and K8s
#
#                                       job_apply_link  job_apply_is_direct  \
# 0  https://lt.linkedin.com/jobs/view/python-devel...                False
# 1  https://lt.linkedin.com/jobs/view/python-devel...                False
# 2  https://lt.linkedin.com/jobs/view/python-devel...                False
# 3  https://lt.linkedin.com/jobs/view/python-engin...                False
# 4  https://lt.linkedin.com/jobs/view/software-eng...                False
#
#    ...  job_salary_currency job_salary_period  job_highlights  \
# 0  ...                 None              None              {}
# 1  ...                 None              None              {}
# 2  ...                 None              None              {}
# 3  ...                 None              None              {}
# 4  ...                 None              None              {}
#
#        job_job_title job_posting_language job_onet_soc job_onet_job_zone  \
# 0               None                   en     15113200                 4
# 1               None                   en     15113200                 4
# 2               None                   en     15113200                 4
# 3           Engineer                   en     15113200                 4
# 4  Software engineer                   en     15113200                 4
#
#   job_naics_code                      job_naics_name  \
# 0          48851  Freight Transportation Arrangement
# 1            NaN                                 NaN
# 2            NaN                                 NaN
# 3            NaN                                 NaN
# 4         511210                 Software Publishers
#
#    job_occupational_categories
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                          NaN
#
# [5 rows x 40 columns]

# %% [markdown]
# # Išsaugoti duomenis
#
# Atkomentuoti eilutes su `CTR + /` ir išsaugoti norimu formatu.
#
# Norint atsisiųsti duomenis lokaliai paspauskite ant dešinėje pusė esančios "Files" ikonos ir atsisiųskite norimą failą. Jei to nepadarysite, failai bus ištrinti uždarius google colab.
#
# ![image info](https://i.stack.imgur.com/mYWnb.png)

# %%
#@title Duomenų formatas

EXCEL = True #@param {type:"boolean"}
CSV = True #@param {type:"boolean"}

# excel formatu
if EXCEL:
  df.to_excel(f"darbai.xlsx", index = False)
# .csv formatu
if CSV:
  df.to_csv(f"darbai.csv", index = False)
